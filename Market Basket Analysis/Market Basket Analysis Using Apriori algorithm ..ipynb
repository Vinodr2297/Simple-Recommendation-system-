# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # reading data from internet

# %%
data = pd.read_excel("http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx")
data.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
data["Country"].value_counts().head(10)
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Netherlands         2371
# Belgium             2069
# Switzerland         2002
# Portugal            1519
# Australia           1259
# Name: Country, dtype: int64

# %% [markdown]
# # Data Preprocessig

# %%
# let me apply apriori algo only on dataset which belongs Germany country .

germany = data[data["Country"] == "Germany"]
germany.head(2)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1109    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
#
#              InvoiceDate  UnitPrice  CustomerID  Country
# 1109 2010-12-01 13:04:00       2.95     12662.0  Germany
# 1110 2010-12-01 13:04:00       2.55     12662.0  Germany

# %%
germany.drop(["StockCode","InvoiceDate","UnitPrice","CustomerID","Country"],axis = 1,inplace = True)

# %%
# check for types of variables
germany.reset_index(drop = True,inplace = True)
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9495 entries, 0 to 9494
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    9495 non-null   object
#  1   Description  9495 non-null   object
#  2   Quantity     9495 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 222.7+ KB

# %%
print(germany.shape)
germany.head(2)
# Out:
# (9495, 3)
#   InvoiceNo                          Description  Quantity
# 0    536527              SET OF 6 T-LIGHTS SANTA         6
# 1    536527  ROTATING SILVER ANGELS T-LIGHT HLDR         6

# %%
germany["Description"].value_counts().head(8)
# Out:
# POSTAGE                                383
# ROUND SNACK BOXES SET OF4 WOODLAND     120
# REGENCY CAKESTAND 3 TIER                81
# ROUND SNACK BOXES SET OF 4 FRUITS       78
# PLASTERS IN TIN WOODLAND ANIMALS        67
# WOODLAND CHARLOTTE BAG                  59
# PLASTERS IN TIN CIRCUS PARADE           57
# PLASTERS IN TIN SPACEBOY                51
# Name: Description, dtype: int64

# %%
germany = germany[germany["Description"]!="POSTAGE"]
germany["Description"].value_counts().head(8)
# Out:
# ROUND SNACK BOXES SET OF4 WOODLAND     120
# REGENCY CAKESTAND 3 TIER                81
# ROUND SNACK BOXES SET OF 4 FRUITS       78
# PLASTERS IN TIN WOODLAND ANIMALS        67
# WOODLAND CHARLOTTE BAG                  59
# PLASTERS IN TIN CIRCUS PARADE           57
# PLASTERS IN TIN SPACEBOY                51
# 6 RIBBONS RUSTIC CHARM                  50
# Name: Description, dtype: int64

# %%
germany["Description"] = germany["Description"].str.strip("")
germany.dropna(axis = 0,inplace = True)
print(germany.shape)
# Out:
# (9112, 3)

# %%
germany.head(2)
# Out:
#   InvoiceNo                          Description  Quantity
# 0    536527              SET OF 6 T-LIGHTS SANTA         6
# 1    536527  ROTATING SILVER ANGELS T-LIGHT HLDR         6

# %%
market_bastket_data = germany.groupby(["InvoiceNo","Description"])["Quantity"].sum().unstack().reset_index().fillna(0).set_index(["InvoiceNo"])

# %%
market_bastket_data.head(2)
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                  0.0                 0.0
# 536840                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                0.0                       0.0
# 536840                                0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536527                                    0.0                      0.0
# 536840                                    0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  ...  \
# InvoiceNo                                     ...
# 536527                                   0.0  ...
# 536840                                   0.0  ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                 0.0                         0.0
# 536840                                 0.0                         0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                              0.0                 0.0
# 536840                              0.0                 0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                             0.0                                0.0
# 536840                             0.0                                0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                               0.0                             0.0
# 536840                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                   0.0                               0.0
# 536840                                   0.0                               0.0
#
# [2 rows x 1702 columns]

# %%
def enocode(x):
    if(x<=0):
        return 0
    elif(x>=1):
        return 1

market_bastket_data = market_bastket_data.applymap(enocode)

# %%
market_bastket_data.head(2)
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                    0                   0
# 536840                                    0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                  0                         0
# 536840                                  0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536527                                      0                        0
# 536840                                      0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                            0                           0
# 536840                            0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                      0
# 536840                                      0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  ...  \
# InvoiceNo                                     ...
# 536527                                     0  ...
# 536840                                     0  ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                   0                           0
# 536840                                   0                           0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                                0                   0
# 536840                                0                   0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                               0                                  0
# 536840                               0                                  0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                                 0                               0
# 536840                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                     0                                 0
# 536840                                     0                                 0
#
# [2 rows x 1702 columns]

# %% [markdown]
# # model building using apriori algo

# %%
# generate frequent itemset
# support is 5%
frequent_items = apriori(market_bastket_data,min_support = 0.05,use_colnames = True)

# %%
frequent_items
# Out:
#      support                                           itemsets
# 0   0.079796                           (6 RIBBONS RUSTIC CHARM)
# 1   0.054329                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.050934                      (CHARLOTTE BAG APPLES DESIGN)
# 3   0.056027                                (GUMBALL COAT RACK)
# 4   0.071307                           (JAM MAKING SET PRINTED)
# 5   0.061121                          (JUMBO BAG RED RETROSPOT)
# 6   0.078098                       (JUMBO BAG WOODLAND ANIMALS)
# 7   0.061121                               (LUNCH BAG WOODLAND)
# 8   0.066214                  (PACK OF 72 RETROSPOT CAKE CASES)
# 9   0.089983                   (PLASTERS IN TIN CIRCUS PARADE )
# 10  0.083192                         (PLASTERS IN TIN SPACEBOY)
# 11  0.054329                        (PLASTERS IN TIN STRONGMAN)
# 12  0.106961                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 13  0.054329                      (RED RETROSPOT CHARLOTTE BAG)
# 14  0.054329                                (RED RETROSPOT CUP)
# 15  0.050934                         (RED RETROSPOT MINI CASES)
# 16  0.074703                    (RED TOADSTOOL LED NIGHT LIGHT)
# 17  0.106961                         (REGENCY CAKESTAND 3 TIER)
# 18  0.122241               (ROUND SNACK BOXES SET OF 4 FRUITS )
# 19  0.190153              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 20  0.054329                       (SET OF 3 REGENCY CAKE TINS)
# 21  0.079796                              (SPACEBOY LUNCH BOX )
# 22  0.061121                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 23  0.098472                           (WOODLAND CHARLOTTE BAG)
# 24  0.052632                 (WOODLAND PARTY BAG + STICKER SET)
# 25  0.052632  (PLASTERS IN TIN CIRCUS PARADE , PLASTERS IN T...
# 26  0.057725  (PLASTERS IN TIN WOODLAND ANIMALS, ROUND SNACK...
# 27  0.101868  (ROUND SNACK BOXES SET OF4 WOODLAND , ROUND SN...
# 28  0.054329  (ROUND SNACK BOXES SET OF4 WOODLAND , SPACEBOY...

# %%
# generate association rules 
# considering lift as metric instead of confidence .

rules = association_rules(frequent_items,metric = 'lift',min_threshold =1)

# %%
rules
# Out:
#                              antecedents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE )
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)
# 2     (PLASTERS IN TIN WOODLAND ANIMALS)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 5   (ROUND SNACK BOXES SET OF 4 FRUITS )
# 6  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 7                  (SPACEBOY LUNCH BOX )
#
#                              consequents  antecedent support  \
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)            0.089983
# 1       (PLASTERS IN TIN CIRCUS PARADE )            0.106961
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.106961
# 3     (PLASTERS IN TIN WOODLAND ANIMALS)            0.190153
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.190153
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.122241
# 6                  (SPACEBOY LUNCH BOX )            0.190153
# 7  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.079796
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.106961  0.052632    0.584906  5.468404  0.043007    2.151412
# 1            0.089983  0.052632    0.492063  5.468404  0.043007    1.791596
# 2            0.190153  0.057725    0.539683  2.838152  0.037386    1.759323
# 3            0.106961  0.057725    0.303571  2.838152  0.037386    1.282312
# 4            0.122241  0.101868    0.535714  4.382440  0.078623    1.890558
# 5            0.190153  0.101868    0.833333  4.382440  0.078623    4.859083
# 6            0.079796  0.054329    0.285714  3.580547  0.039156    1.288285
# 7            0.190153  0.054329    0.680851  3.580547  0.039156    2.537521

# %% [markdown]
# # Make recommendations

# %% [raw]
# # setting thershold
# 1 . lift > 1
# 2 . confidence > 0.5 (50 %)

# %%
rules[(rules["lift"]>1) & (rules["confidence"]>0.5)]
# Out:
#                              antecedents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE )
# 2     (PLASTERS IN TIN WOODLAND ANIMALS)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 5   (ROUND SNACK BOXES SET OF 4 FRUITS )
# 7                  (SPACEBOY LUNCH BOX )
#
#                              consequents  antecedent support  \
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)            0.089983
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.106961
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.190153
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.122241
# 7  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.079796
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.106961  0.052632    0.584906  5.468404  0.043007    2.151412
# 2            0.190153  0.057725    0.539683  2.838152  0.037386    1.759323
# 4            0.122241  0.101868    0.535714  4.382440  0.078623    1.890558
# 5            0.190153  0.101868    0.833333  4.382440  0.078623    4.859083
# 7            0.190153  0.054329    0.680851  3.580547  0.039156    2.537521

# %% [raw]
# # Example 1 :
#
# customer who purchased "PLASTERS IN TIN WOODLAND ANIMALS" will also purchase "ROUND SNACK BOXES SET OF4 WOODLAND" with
# confidence  = 50% ,lift >1

# %% [raw]
# # Example 2 :
#
# customer who purchased "SPACEBOY LUNCH BOX" will also purchase "ROUND SNACK BOXES SET OF4 WOODLAND" with
# confidence  = 68% ,lift >1
